# %%
import sys
import numpy as np
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import StandardScaler
import shap
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, roc_curve, auc
data = pd.read_csv("D:\pythonProject7\库存合并3.csv")
print(data)
row_0 = list(data.loc[0])
row_num = data.iloc[:,0].size

print("data len: {}".format(len(row_0)))
print("row_num: {}".format(row_num))

y_list = []   # 用于存放标签数据
x_list = []   # 用于存放特征数据
for i in range(row_num):
    row_data_list = list(data.loc[i])
    y_list.append(row_data_list[0])
    x_list.append(row_data_list[1:])

# 将数据类型由 list 转换为 array
x_array = np.array(x_list)
y_array = np.array(y_list)

print("x_array shape: {}".format(x_array.shape))
print("y_array shape: {}".format(y_array.shape))
print("==================== Column Name ====================")
print(list(data.columns))
# test_size=0.2   设置测试集的样本数量为全部样呗的 20%
# random_state=12 设置随机种子为 12
# shuffle=True    打乱样本数据的顺序
x_train, x_test, y_train, y_test = train_test_split(x_array, y_array, test_size=0.2, random_state=42, shuffle=True)
# 特征归一化
scaler = StandardScaler()
x_array = scaler.fit_transform(x_array)
x_array = scaler.transform(x_array)
print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))
print("x_test  shape: {}".format(x_test.shape))
print("y_test  shape: {}".format(y_test.shape))
# n_estimators：森林中决策树的数量




rf = RandomForestRegressor(n_estimators=100, max_depth=10,random_state=42)
rf.fit(x_train, y_train)
predict_value = rf.predict(x_test)
for idx,value in enumerate(predict_value):
    print("[predict]: idx = {}, label = {}, predict = {}".format(idx, y_test[idx], value))
 
# 计算均方差
mse = mean_squared_error(y_test,predict_value)

    # 记录均方差
#mse_list.append(mse)

# 输出均方差
print(f"Mean squared error: {mse}")
# 我们记录在文件中的数据的特征参数名称
columns_name_list = [ 'WMHD/1000', 'BETAP', 'PLHI2/1000', 'PNBI1LSOURCE/1000', 'PNBI1RSOURCE/1000', 'PNBI2LSOURCE/1000', 'PNBI2RSOURCE/1000', 'G109', 'G107', 'G106', 'KAPPA', 'AMINOR', 'Q95', 'LI', 'TRITOP', 'TRIBOT', 'DRSEP', 'PXUV33', 'PXUV7', 'WUta', 'pcrl01/1000000', 'pecrh', 'n3/n6']
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(x_test)
shap.summary_plot(shap_values, x_test, feature_names=columns_name_list)
importances = rf.feature_importances_
# 可视化特征的影响度
feature_names = data.columns[1:24]  # 特征名称
indices = np.argsort(importances)[::-1]
plt.figure()
plt.title("Feature Importances")
plt.bar(range(x_array.shape[1]), importances[indices])
plt.xticks(range(x_array.shape[1]), feature_names[indices], rotation=90)  # 设置 x 轴标签
plt.xlabel("Features")
plt.ylabel("Importance")
plt.show()
# Out:
#       dfsdev2   WMHD/1000     BETAP  PLHI2/1000  PNBI1LSOURCE/1000  \
# 0    3.786213  150.062665  1.809148    1.771008          -0.000024
# 1    3.814039  153.717101  1.872722    1.764905          -0.000002
# 2    3.902733  154.320308  1.913145    1.764600           0.000090
# 3    3.877649  154.758403  1.988600    1.766736          -0.000053
# 4    3.836375  155.324920  2.058595    1.759717          -0.000014
# ..        ...         ...       ...         ...                ...
# [predict]: idx = 134, label = 6.639268893, predict = 6.588242135419786
# [predict]: idx = 135, label = 6.954217533, predict = 6.7846304576203105
# [predict]: idx = 136, label = 4.515405058, predict = 4.53335030624078
# [predict]: idx = 137, label = 6.953881912, predict = 6.951165785133991
# [predict]: idx = 138, label = 4.442479447, predict = 4.4669739732832685
# [predict]: idx = 139, label = 7.239967676, predict = 7.183242475852833
# [predict]: idx = 140, label = 6.401386602, predict = 6.302501971449804
# [predict]: idx = 141, label = 5.856078371, predict = 5.933946427766699
# [predict]: idx = 142, label = 5.352565242, predict = 5.382733449267801
# [predict]: idx = 143, label = 6.632443572, predict = 6.5759785472655805
# [predict]: idx = 144, label = 5.734954402, predict = 5.879638049728729
# [predict]: idx = 145, label = 6.306479767, predict = 6.4247335260310505
# [predict]: idx = 146, label = 6.439877163, predict = 6.486028402467521
# [predict]: idx = 147, label = 4.494942523, predict = 4.481794418986306
# [predict]: idx = 148, label = 6.666008519, predict = 6.658894785241837
# [predict]: idx = 149, label = 6.447767101, predict = 6.543205234157922
# [predict]: idx = 150, label = 6.942279866, predict = 6.877382937740686
# [predict]: idx = 151, label = 3.837023847, predict = 3.961856275288331
# [predict]: idx = 152, label = 6.230711203, predict = 6.266082479618716
# [predict]: idx = 153, label = 6.196491949, predict = 6.269675625914988
# [predict]: idx = 154, label = 5.001724255, predict = 5.020915343364174
# [predict]: idx = 155, label = 5.943502023, predict = 5.948847090142888
# [predict]: idx = 156, label = 4.772742526, predict = 4.626723481658789
# [predict]: idx = 157, label = 4.339784654, predict = 4.557312437721554
# [predict]: idx = 158, label = 4.83529604, predict = 4.888415552885937
# [predict]: idx = 159, label = 3.902733023, predict = 3.846540995467296
# [predict]: idx = 160, label = 7.087650227, predict = 6.340691605564404
# [predict]: idx = 161, label = 6.604382929, predict = 6.539169005147102
# [predict]: idx = 162, label = 6.547918756, predict = 6.447889352715996
# [predict]: idx = 163, label = 6.605156691, predict = 6.641005918314208
# [predict]: idx = 164, label = 5.430285711, predict = 5.518383656895237
# [predict]: idx = 165, label = 7.323671777, predict = 7.147557814749767
# [predict]: idx = 166, label = 3.656691258, predict = 3.6889729608100015
# [predict]: idx = 167, label = 6.304577156, predict = 6.401268795383402
# Mean squared error: 0.03256926739088536

# %%
from sklearn.model_selection import GridSearchCV 
param_grid = {'max_depth':np.arange(1, 20, 1)}

GS = GridSearchCV(rf,param_grid,cv=10) 
GS.fit(x_array,y_array)
print(GS.best_params_)
print(GS.best_score_)
# Out:
# {'max_depth': 13}
# 0.7306588320372861

# %%
for i, tree in enumerate(rf.estimators_):
    max_depth = tree.tree_.max_depth
    print(f"Tree {i+1} - Max Depth: {max_depth}")
# Out:
# Tree 1 - Max Depth: 10
# Tree 2 - Max Depth: 10
# Tree 3 - Max Depth: 10
# Tree 4 - Max Depth: 10
# Tree 5 - Max Depth: 10
# Tree 6 - Max Depth: 10
# Tree 7 - Max Depth: 10
# Tree 8 - Max Depth: 10
# Tree 9 - Max Depth: 10
# Tree 10 - Max Depth: 10
# Tree 11 - Max Depth: 10
# Tree 12 - Max Depth: 10
# Tree 13 - Max Depth: 10
# Tree 14 - Max Depth: 10
# Tree 15 - Max Depth: 10
# Tree 16 - Max Depth: 10
# Tree 17 - Max Depth: 10
# Tree 18 - Max Depth: 10
# Tree 19 - Max Depth: 10
# Tree 20 - Max Depth: 10
# Tree 21 - Max Depth: 10
# Tree 22 - Max Depth: 10
# Tree 23 - Max Depth: 10
# Tree 24 - Max Depth: 10
# Tree 25 - Max Depth: 10
# Tree 26 - Max Depth: 10
# Tree 27 - Max Depth: 10
# Tree 28 - Max Depth: 10
# Tree 29 - Max Depth: 10
# Tree 30 - Max Depth: 10
# Tree 31 - Max Depth: 10
# Tree 32 - Max Depth: 10
# Tree 33 - Max Depth: 10
# Tree 34 - Max Depth: 10
# Tree 35 - Max Depth: 10
# Tree 36 - Max Depth: 10
# Tree 37 - Max Depth: 10
# Tree 38 - Max Depth: 10
# Tree 39 - Max Depth: 10
# Tree 40 - Max Depth: 10
# Tree 41 - Max Depth: 10
# Tree 42 - Max Depth: 10
# Tree 43 - Max Depth: 10
# Tree 44 - Max Depth: 10
# Tree 45 - Max Depth: 10
# Tree 46 - Max Depth: 10
# Tree 47 - Max Depth: 10
# Tree 48 - Max Depth: 10
# Tree 49 - Max Depth: 10
# Tree 50 - Max Depth: 10
# Tree 51 - Max Depth: 10
# Tree 52 - Max Depth: 10
# Tree 53 - Max Depth: 10
# Tree 54 - Max Depth: 10
# Tree 55 - Max Depth: 10
# Tree 56 - Max Depth: 10
# Tree 57 - Max Depth: 10
# Tree 58 - Max Depth: 10
# Tree 59 - Max Depth: 10
# Tree 60 - Max Depth: 10
# Tree 61 - Max Depth: 10
# Tree 62 - Max Depth: 10
# Tree 63 - Max Depth: 10
# Tree 64 - Max Depth: 10
# Tree 65 - Max Depth: 10
# Tree 66 - Max Depth: 10
# Tree 67 - Max Depth: 10
# Tree 68 - Max Depth: 10
# Tree 69 - Max Depth: 10
# Tree 70 - Max Depth: 10
# Tree 71 - Max Depth: 10
# Tree 72 - Max Depth: 10
# Tree 73 - Max Depth: 10
# Tree 74 - Max Depth: 10
# Tree 75 - Max Depth: 10
# Tree 76 - Max Depth: 10
# Tree 77 - Max Depth: 10
# Tree 78 - Max Depth: 10
# Tree 79 - Max Depth: 10
# Tree 80 - Max Depth: 10
# Tree 81 - Max Depth: 10
# Tree 82 - Max Depth: 10
# Tree 83 - Max Depth: 10
# Tree 84 - Max Depth: 10
# Tree 85 - Max Depth: 10
# Tree 86 - Max Depth: 10
# Tree 87 - Max Depth: 10
# Tree 88 - Max Depth: 10
# Tree 89 - Max Depth: 10
# Tree 90 - Max Depth: 10
# Tree 91 - Max Depth: 10
# Tree 92 - Max Depth: 10
# Tree 93 - Max Depth: 10
# Tree 94 - Max Depth: 10
# Tree 95 - Max Depth: 10
# Tree 96 - Max Depth: 10
# Tree 97 - Max Depth: 10
# Tree 98 - Max Depth: 10
# Tree 99 - Max Depth: 10
# Tree 100 - Max Depth: 10
