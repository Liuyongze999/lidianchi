# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

import numpy as np


# 命名规范
v_columns = ["V"+str(i) for i in range(1,18)]
TSU_columns = ["TSU"+str(i) for i in range(1,18)]
TSD_columns = ["TSD"+str(i) for i in range(1,18)]
TU_columns = ["TU"+str(i) for i in range(1,18)]
TD_columns = ["TD"+str(i) for i in range(1,18)]

data_path = './锂离子电池生产参数调控及生产温度预测挑战赛公开数据-初赛/'
traindata = pd.read_csv(data_path + 'train.csv')
testdata = pd.read_csv(data_path + 'test.csv')
submit = pd.read_csv('./提交示例.csv')
submit.head()
traindata=traindata.drop(1057)

# %%
traindata.columns = ["Num","Time"]\
+v_columns\
+TSU_columns\
+TSD_columns\
+TU_columns\
+TD_columns

testdata.columns = ["Num","Time"]\
+v_columns\
+TSU_columns\
+TSD_columns\

submit.columns = ["Num"]\
+TU_columns\
+TD_columns

# traindata.drop(["Num","Time"],axis=1,inplace=True)
# testdata.drop(["Num","Time"],axis=1,inplace=True)
traindata.head()
# Out:
#    Num            Time         V1         V2         V3         V4         V5  \
# 0    1  2022/11/6 9:08  35.668999  36.146000  25.558001  26.195000  25.670000
# 1    2  2022/11/6 9:09  35.995998  36.347000  25.382000  26.348000  26.131001
# 2    3  2022/11/6 9:11  35.340000  36.311001  25.469999  26.093000  25.639000
# 3    4  2022/11/6 9:12  35.585999  36.091000  25.250000  26.127001  25.670000
# 4    5  2022/11/6 9:13  35.946999  36.256001  25.163000  26.399000  25.837999
#
#        V6         V7      V8  ...  TD8  TD9  TD10  TD11  TD12  TD13  TD14  \
# 0  15.702  16.690001  15.991  ...  827  827   827   827   827   827   827
# 1  15.523  16.825001  15.871  ...  827  827   827   827   827   827   827
# 2  15.564  15.564000  15.947  ...  827  827   827   827   827   827   827
# 3  15.575  16.775999  15.936  ...  827  827   827   827   827   827   827
# 4  15.460  16.580999  15.795  ...  827  827   827   827   827   827   827
#
#    TD15  TD16  TD17
# 0   827   827   750
# 1   827   827   750
# 2   827   827   750
# 3   827   827   750
# 4   827   827   750
#
# [5 rows x 87 columns]

# %%
label = ["TU"+str(i) for i in range(1,18)]\
+["TD"+str(i) for i in range(1,18)]

features = ["V"+str(i) for i in range(1,18)]\
+["TSU"+str(i) for i in range(1,18)]\
+["TSD"+str(i) for i in range(1,18)]
## 构造V 流量特征  VB
## V和VB1  V均值VB2
traindata["VB1"] = traindata[v_columns].apply(lambda x:x.sum(),axis=1)
traindata["VB2"] = traindata[v_columns].apply(lambda x:x.sum()/17,axis=1)
testdata["VB1"] = testdata[v_columns].apply(lambda x:x.sum(),axis=1)
testdata["VB2"] = testdata[v_columns].apply(lambda x:x.sum()/17,axis=1)

# %%
## V上面7个和  均值
traindata["VB3"] = traindata[v_columns[:7]].apply(lambda x:x.sum(),axis=1)
traindata["VB4"] = traindata[v_columns[:7]].apply(lambda x:x.sum()/7,axis=1)
testdata["VB3"] = testdata[v_columns[:7]].apply(lambda x:x.sum(),axis=1)
testdata["VB4"] = testdata[v_columns[:7]].apply(lambda x:x.sum()/7,axis=1)

## 利用时间 构造流量速率特征  对于我们只预测TU1-7那就再只做一下V1-7的流速
## 流速VS1-17 命名  注意这里还没有取绝对值  也就是说 这里的流速有正负值  同理17个流速都可以获得
## 这里直接做VS1-17的流速
traindata["Time1"] = pd.to_datetime(traindata["Time"]) - pd.to_datetime(traindata["Time"].shift(periods=1))
testdata["Time1"] = pd.to_datetime(testdata["Time"]) - pd.to_datetime(testdata["Time"].shift(periods=1))
# 筛选时差20分钟内  且不为0 的index
indexset = traindata[(traindata["Time1"] <= pd.Timedelta(days=0, minutes=20)) & (traindata["Time1"] != pd.Timedelta(days=0, minutes=0))].index

# %%
for i in range(1,18):
    traindata["VS"+str(i)] = np.nan
    traindata.loc[indexset,"VS"+str(i)] = (traindata.loc[indexset]["V"+str(i)] - traindata.loc[indexset]["V"+str(i)].shift(periods=1)) / traindata.loc[indexset]["Time1"].apply(lambda x:x.seconds//60)
    traindata.loc[indexset,"VS"+str(i)]
    # 后值填充  又做了个取绝对值
    traindata["VS"+str(i)] = traindata["VS"+str(i)].fillna(method="bfill").apply(lambda x:abs(x))
# 筛选时差20分钟内  且不为0 的index
indexset = testdata[(traindata["Time1"] <= pd.Timedelta(days=0, minutes=20)) & (testdata["Time1"] != pd.Timedelta(days=0, minutes=0))].index
for i in range(1,18):
    testdata["VS"+str(i)] = np.nan
    testdata.loc[indexset,"VS"+str(i)] = (testdata.loc[indexset]["V"+str(i)] - testdata.loc[indexset]["V"+str(i)].shift(periods=1)) / testdata.loc[indexset]["Time1"].apply(lambda x:x.seconds//60)
    testdata.loc[indexset,"VS"+str(i)]
    # 后值填充  又做了个取绝对值
    testdata["VS"+str(i)] = testdata["VS"+str(i)].fillna(method="bfill").apply(lambda x:abs(x))
## 加热棒设定温度和流量的比值
## TSUV  TSDV
for i in range(1,18):
    traindata["TSUV"+str(i)] = traindata["TSU"+str(i)] / traindata["V"+str(i)]
    traindata["TSDV"+str(i)] = traindata["TSD"+str(i)] / traindata["V"+str(i)]
    ## 加热棒设定温度和流量的比值
## TSUV  TSDV
for i in range(1,18):
    testdata["TSUV"+str(i)] = testdata["TSU"+str(i)] / testdata["V"+str(i)]
    testdata["TSDV"+str(i)] = testdata["TSD"+str(i)] / testdata["V"+str(i)]

##判断是否工作日  没有用
traindata["day"] = pd.to_datetime(traindata["Time"]).apply(lambda x:x.dayofweek)
testdata["day"] = pd.to_datetime(testdata["Time"]).apply(lambda x:x.dayofweek)
# Out:
# C:\Users\liuchen\AppData\Local\Temp\ipykernel_944\2316982202.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   indexset = testdata[(traindata["Time1"] <= pd.Timedelta(days=0, minutes=20)) & (testdata["Time1"] != pd.Timedelta(days=0, minutes=0))].index

# %%
print(testdata.head())

newtraindata=pd.DataFrame(traindata.drop(['Time1', 'Time','TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TU8', 'TU9', 'TU10', 'TU11', 'TU12', 'TU13', 'TU14', 'TU15', 'TU16', 'TU17', 'TD1', 'TD2', 'TD3', 'TD4', 'TD5', 'TD6', 'TD7', 'TD8', 'TD9', 'TD10', 'TD11', 'TD12', 'TD13', 'TD14', 'TD15', 'TD16', 'TD17'], axis=1)),
print(traindata.head())
features = traindata.drop(['Time1', 'Time','TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TU8', 'TU9', 'TU10', 'TU11', 'TU12', 'TU13', 'TU14', 'TU15', 'TU16', 'TU17', 'TD1', 'TD2', 'TD3', 'TD4', 'TD5', 'TD6', 'TD7', 'TD8', 'TD9', 'TD10', 'TD11', 'TD12', 'TD13', 'TD14', 'TD15', 'TD16', 'TD17'], axis=1)
target = traindata['TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7','TD1','TD2','TD5']
# Out:
#    Num           Time         V1         V2         V3         V4         V5  \
# 0    1  2023/3/1 4:15  24.222000  24.070000  28.889000  25.264999  26.827999
# 1    2  2023/3/1 4:20  24.138000  23.974001  28.798000  25.517000  27.108999
# 2    3  2023/3/1 4:26  24.152000  24.006001  28.827999  25.114000  26.719999
# 3    4  2023/3/1 4:31  24.108999  23.974001  28.783001  25.114000  27.047001
# 4    5  2023/3/1 4:36  24.350000  24.215000  29.146999  25.416000  25.416000
#
#       V6      V7         V8  ...     TSDV13     TSUV14     TSDV14     TSUV15  \
# 0  4.354  21.784  24.323000  ...  62.687237  61.926606  61.926606  46.518090
# 1  4.377  21.886  24.384001  ...  63.155511  62.701326  62.701326  47.115116
# 2  4.293  21.611  24.099001  ...  62.842555  62.392844  62.392844  46.798993
# 3  4.354  21.857  24.337999  ...  63.050849  62.649702  62.649702  47.186828
# 4  4.377  21.900  24.444000  ...  60.560017  61.926606  61.926606  46.658121
#
#       TSDV15     TSUV16     TSDV16     TSUV17     TSDV17  day
# 0  46.518090  50.500786  50.500786  18.688329  18.688329    2
# 1  47.115116  50.607656  50.607656  18.727059  18.727059    2
# 2  46.798993  46.798993  46.798993  18.704641  18.704641    2
# 3  47.186828  50.467293  50.467293  18.712574  18.712574    2
# 4  46.658121  50.225020  50.225020  18.594734  18.594734    2
#
# [5 rows x 110 columns]
#    Num            Time         V1         V2         V3         V4         V5  \
# 0    1  2022/11/6 9:08  35.668999  36.146000  25.558001  26.195000  25.670000
# 1    2  2022/11/6 9:09  35.995998  36.347000  25.382000  26.348000  26.131001
# 2    3  2022/11/6 9:11  35.340000  36.311001  25.469999  26.093000  25.639000
# 3    4  2022/11/6 9:12  35.585999  36.091000  25.250000  26.127001  25.670000
# 4    5  2022/11/6 9:13  35.946999  36.256001  25.163000  26.399000  25.837999
#
#        V6         V7      V8  ...     TSDV13     TSUV14     TSDV14     TSUV15  \
# 0  15.702  16.690001  15.991  ...  55.927505  52.678513  52.678513  50.848500
# 1  15.523  16.825001  15.871  ...  55.965350  52.644982  52.644982  50.814133
# 2  15.564  15.564000  15.947  ...  55.855735  52.644982  52.644982  50.848500
# 3  15.575  16.775999  15.936  ...  55.927505  52.644982  52.644982  50.848500
# 4  15.460  16.580999  15.795  ...  55.784149  52.644982  52.644982  50.951879
#
#       TSDV15     TSUV16     TSDV16     TSUV17     TSDV17  day
# 0  50.848500  48.388042  48.388042  15.798121  15.798121    6
# 1  50.814133  48.388042  48.388042  15.776853  15.776853    6
# 2  50.848500  48.388042  48.388042  15.798121  15.798121    6
# 3  50.848500  48.524323  48.524323  15.855567  15.855567    6
# 4  50.951879  48.182243  48.182243  15.769554  15.769554    6
#
# [5 rows x 144 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TD1', 'TD2', 'TD5')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_944\3536975302.py in <module>
#       4 print(traindata.head())
#       5 features = traindata.drop(['Time1', 'Time','TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TU8', 'TU9', 'TU10', 'TU11', 'TU12', 'TU13', 'TU14', 'TU15', 'TU16', 'TU17', 'TD1', 'TD2', 'TD3', 'TD4', 'TD5', 'TD6', 'TD7', 'TD8', 'TD9', 'TD10', 'TD11', 'TD12', 'TD13', 'TD14', 'TD15', 'TD16', 'TD17'], axis=1)
# ----> 6 target = traindata['TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7','TD1','TD2','TD5']
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TD1', 'TD2', 'TD5')

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor().fit(
traindata.drop(['Time1', 'Time','TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TU8', 'TU9', 'TU10', 'TU11', 'TU12', 'TU13', 'TU14', 'TU15', 'TU16', 'TU17', 'TD1', 'TD2', 'TD3', 'TD4', 'TD5', 'TD6', 'TD7', 'TD8', 'TD9', 'TD10', 'TD11', 'TD12', 'TD13', 'TD14', 'TD15', 'TD16', 'TD17'], axis=1),traindata['TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TD1', 'TD2', 'TD5'])
submit = model.predict(testdata.drop(['Time','Time1'], axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TD1', 'TD2', 'TD5')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_944\2980255601.py in <module>
#       2
#       3 model = RandomForestRegressor().fit(
# ----> 4 traindata.drop(['Time1', 'Time','TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TU8', 'TU9', 'TU10', 'TU11', 'TU12', 'TU13', 'TU14', 'TU15', 'TU16', 'TU17', 'TD1', 'TD2', 'TD3', 'TD4', 'TD5', 'TD6', 'TD7', 'TD8', 'TD9', 'TD10', 'TD11', 'TD12', 'TD13', 'TD14', 'TD15', 'TD16', 'TD17'], axis=1),traindata['TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TD1', 'TD2', 'TD5'])
#       5 submit = model.predict(testdata.drop(['Time','Time1'], axis=1))
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# D:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('TU1', 'TU2', 'TU3', 'TU4', 'TU5', 'TU6', 'TU7', 'TD1', 'TD2', 'TD5')
